# %% [markdown]
# <a href="https://colab.research.google.com/github/pavi38/icp1/blob/main/icp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# selecting the numeric data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasets/hepatitis/master/data/hepatitis.csv')
numeric_df = df.select_dtypes(include=np.number).copy()
numeric_df
# Out:
#      age  bilirubin  alk_phosphate   sgot  albumin  protime
# 0     30        1.0           85.0   18.0      4.0      NaN
# 1     50        0.9          135.0   42.0      3.5      NaN
# 2     78        0.7           96.0   32.0      4.0      NaN
# 3     31        0.7           46.0   52.0      4.0     80.0
# 4     34        1.0            NaN  200.0      4.0      NaN
# ..   ...        ...            ...    ...      ...      ...
# 150   46        7.6            NaN  242.0      3.3     50.0
# 151   44        0.9          126.0  142.0      4.3      NaN
# 152   61        0.8           75.0   20.0      4.1      NaN
# 153   53        1.5           81.0   19.0      4.1     48.0
# 154   43        1.2          100.0   19.0      3.1     42.0
#
# [155 rows x 6 columns]

# %% [markdown]
# Seeing how much data is missing.

# %%
numeric_df.isna().sum()
# Out:
# age               0
# bilirubin         6
# alk_phosphate    29
# sgot              4
# albumin          16
# protime          67
# dtype: int64

# %%
numeric_df.mean()
# Out:
# age               41.200000
# bilirubin          1.427517
# alk_phosphate    105.325397
# sgot              85.894040
# albumin            3.817266
# protime           61.852273
# dtype: float64

# %% [markdown]
# Solution:
#
# Replacing all the missing data with the mean of the column

# %%
filled_df = numeric_df.fillna(value = numeric_df.mean()).copy()
filled_df
# Out:
#      age  bilirubin  alk_phosphate   sgot  albumin    protime
# 0     30        1.0      85.000000   18.0      4.0  61.852273
# 1     50        0.9     135.000000   42.0      3.5  61.852273
# 2     78        0.7      96.000000   32.0      4.0  61.852273
# 3     31        0.7      46.000000   52.0      4.0  80.000000
# 4     34        1.0     105.325397  200.0      4.0  61.852273
# ..   ...        ...            ...    ...      ...        ...
# 150   46        7.6     105.325397  242.0      3.3  50.000000
# 151   44        0.9     126.000000  142.0      4.3  61.852273
# 152   61        0.8      75.000000   20.0      4.1  61.852273
# 153   53        1.5      81.000000   19.0      4.1  48.000000
# 154   43        1.2     100.000000   19.0      3.1  42.000000
#
# [155 rows x 6 columns]

# %% [markdown]
# Hence, Now we have no missing data.

# %%
filled_df.isna().sum()
# Out:
# age              0
# bilirubin        0
# alk_phosphate    0
# sgot             0
# albumin          0
# protime          0
# dtype: int64
